# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd
import numpy as np

# %%
POUT = pd.read_csv("KOB_ANISO_256S_1028ITERS/PHASE_1028.csv")
plt.figure(figsize=(10,6))
plt.imshow(POUT)
plt.colorbar()
plt.show()

# %%
POUT = pd.read_csv("KOB_ISO_512S_1024ITERS/TempOut_1024.csv")
plt.figure(figsize=(8,8))

plt.imshow(POUT)
plt.colorbar()
plt.savefig("./Images/KobAnisoT0.png")
